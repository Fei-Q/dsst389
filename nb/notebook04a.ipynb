# %% [markdown]
# <a href="https://colab.research.google.com/github/Fei-Q/dsst389/blob/main/nb/notebook04a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Notebook04a

# %% [markdown]
# ### Setup

# %% [markdown]
# Run all of the following before starting the notebook.

# %%
! wget -q -nc https://raw.githubusercontent.com/taylor-arnold/fds-py/refs/heads/main/funs.py

# %%
import numpy as np
import polars as pl

from funs import *
from plotnine import *
from polars import col as c
theme_set(theme_minimal())

ub = "https://raw.githubusercontent.com/taylor-arnold/fds-py-nb/refs/heads/main/"

# %%
movie = pl.read_csv(ub + "data/movies_50_years.csv")
color = pl.read_csv(ub + "data/movies_50_years_color.csv")
genre = pl.read_csv(ub + "data/movies_50_years_genre.csv")
people = pl.read_csv(ub + "data/movies_50_years_people.csv")

# %% [markdown]
# ### Questions

# %% [markdown]
# In this notebook, we will learn how to combine information from multiple datasets using joins. The movie data has been split into several tables: `movie` contains basic information about each film (runtime, rating, etc.), `genre` lists the genres associated with each film, `color` contains information about the colors in each movie's poster, and `people` has information about the cast and crew. Because some movie titles are duplicated across different years, we will always join by both year and title to ensure we match records correctly.

# %%
movie.head()
# Out:
# shape: (5, 12)
# ┌──────┬──────────────┬─────┬─────────┬───┬──────────────┬─────────────┬─────────────┬─────────────┐
# │ year ┆ title        ┆ mpa ┆ runtime ┆ … ┆ poster_brigh ┆ poster_satu ┆ poster_edge ┆ description │
# │ ---  ┆ ---          ┆ --- ┆ ---     ┆   ┆ tness        ┆ ration      ┆ ness        ┆ ---         │
# │ i64  ┆ str          ┆ str ┆ i64     ┆   ┆ ---          ┆ ---         ┆ ---         ┆ str         │
# │      ┆              ┆     ┆         ┆   ┆ f64          ┆ f64         ┆ f64         ┆             │
# ╞══════╪══════════════╪═════╪═════════╪═══╪══════════════╪═════════════╪═════════════╪═════════════╡
# │ 1970 ┆ Love Story   ┆ PG  ┆ 100     ┆ … ┆ 79.039734    ┆ 8.029792    ┆ 4.586166    ┆ A boy and a │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ girl from   │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ differen…   │
# │ 1970 ┆ Airport      ┆ G   ┆ 137     ┆ … ┆ 70.73516     ┆ 29.284572   ┆ 4.954735    ┆ A bomber on │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ board an    │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ airplane,…  │
# │ 1970 ┆ MASH         ┆ R   ┆ 116     ┆ … ┆ 74.540002    ┆ 40.103629   ┆ 3.510285    ┆ The staff   │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ of a Korean │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ War fiel…   │
# │ 1970 ┆ Patton       ┆ GP  ┆ 172     ┆ … ┆ 83.128991    ┆ 17.43385    ┆ 3.657574    ┆ The World   │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ War II      │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ phase of    │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ the …       │
# │ 1970 ┆ The          ┆ G   ┆ 78      ┆ … ┆ 79.794746    ┆ 12.481992   ┆ 4.400358    ┆ With the    │
# │      ┆ AristoCats   ┆     ┆         ┆   ┆              ┆             ┆             ┆ help of a   │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ smooth      │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ talk…       │
# └──────┴──────────────┴─────┴─────────┴───┴──────────────┴─────────────┴─────────────┴─────────────┘

# %% [markdown]
# Create a new column in the `movie` dataset that computes the ratio of the number of ratings to the runtime. This gives a rough sense of audience engagement per minute of film.

# %%
(
    movie
    .with_columns(
        ratings_per_min=c.rating/c.runtime
    )
)
# Out:
# shape: (5_000, 13)
# ┌──────┬─────────────┬───────┬─────────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ year ┆ title       ┆ mpa   ┆ runtime ┆ … ┆ poster_satu ┆ poster_edge ┆ description ┆ ratings_per │
# │ ---  ┆ ---         ┆ ---   ┆ ---     ┆   ┆ ration      ┆ ness        ┆ ---         ┆ _min        │
# │ i64  ┆ str         ┆ str   ┆ i64     ┆   ┆ ---         ┆ ---         ┆ str         ┆ ---         │
# │      ┆             ┆       ┆         ┆   ┆ f64         ┆ f64         ┆             ┆ f64         │
# ╞══════╪═════════════╪═══════╪═════════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ 1970 ┆ Love Story  ┆ PG    ┆ 100     ┆ … ┆ 8.029792    ┆ 4.586166    ┆ A boy and a ┆ 0.069       │
# │      ┆             ┆       ┆         ┆   ┆             ┆             ┆ girl from   ┆             │
# │      ┆             ┆       ┆         ┆   ┆             ┆             ┆ differen…   ┆             │
# │ 1970 ┆ Airport     ┆ G     ┆ 137     ┆ … ┆ 29.284572   ┆ 4.954735    ┆ A bomber on ┆ 0.048175    │
# │      ┆             ┆       ┆         ┆   ┆             ┆             ┆ board an    ┆             │
# │      ┆             ┆       ┆         ┆   ┆             ┆             ┆ airplane,…  ┆             │
# │ 1970 ┆ MASH        ┆ R     ┆ 116     ┆ … ┆ 40.103629   ┆ 3.510285    ┆ The staff   ┆ 0.064655    │
# │      ┆             ┆       ┆         ┆   ┆             ┆             ┆ of a Korean ┆             │
# │      ┆             ┆       ┆         ┆   ┆             ┆             ┆ War fiel…   ┆             │
# │ 1970 ┆ Patton      ┆ GP    ┆ 172     ┆ … ┆ 17.43385    ┆ 3.657574    ┆ The World   ┆ 0.04593     │
# │      ┆             ┆       ┆         ┆   ┆             ┆             ┆ War II      ┆             │
# │      ┆             ┆       ┆         ┆   ┆             ┆             ┆ phase of    ┆             │
# │      ┆             ┆       ┆         ┆   ┆             ┆             ┆ the …       ┆             │
# │ 1970 ┆ The         ┆ G     ┆ 78      ┆ … ┆ 12.481992   ┆ 4.400358    ┆ With the    ┆ 0.091026    │
# │      ┆ AristoCats  ┆       ┆         ┆   ┆             ┆             ┆ help of a   ┆             │
# │      ┆             ┆       ┆         ┆   ┆             ┆             ┆ smooth      ┆             │
# │      ┆             ┆       ┆         ┆   ┆             ┆             ┆ talk…       ┆             │
# │ …    ┆ …           ┆ …     ┆ …       ┆ … ┆ …           ┆ …           ┆ …           ┆ …           │
# │ 2019 ┆ The Art of  ┆ R     ┆ 104     ┆ … ┆ 67.429893   ┆ 3.232832    ┆ After being ┆ 0.064423    │
# │      ┆ Self-Defens ┆       ┆         ┆   ┆             ┆             ┆ attacked on ┆             │
# │      ┆ e           ┆       ┆         ┆   ┆             ┆             ┆ the st…     ┆             │
# │ 2019 ┆ Luce        ┆ R     ┆ 109     ┆ … ┆ 5.941685    ┆ 2.307601    ┆ A married   ┆ 0.062385    │
# │      ┆             ┆       ┆         ┆   ┆             ┆             ┆ couple is   ┆             │
# │      ┆             ┆       ┆         ┆   ┆             ┆             ┆ forced to … ┆             │
# │ 2019 ┆ The Other   ┆ PG-13 ┆ 117     ┆ … ┆ 39.572749   ┆ 2.307937    ┆ Missionary  ┆ 0.04359     │
# │      ┆ Side of     ┆       ┆         ┆   ┆             ┆             ┆ John H.     ┆             │
# │      ┆ Heaven 2:   ┆       ┆         ┆   ┆             ┆             ┆ Groberg     ┆             │
# │      ┆ Fi…         ┆       ┆         ┆   ┆             ┆             ┆ ret…        ┆             │
# │ 2019 ┆ The         ┆ R     ┆ 108     ┆ … ┆ 36.364627   ┆ 2.137566    ┆ Post World  ┆ 0.058333    │
# │      ┆ Aftermath   ┆       ┆         ┆   ┆             ┆             ┆ War II, a   ┆             │
# │      ┆             ┆       ┆         ┆   ┆             ┆             ┆ British c…  ┆             │
# │ 2019 ┆ The Kid     ┆ R     ┆ 100     ┆ … ┆ 40.325301   ┆ 3.192685    ┆ The story   ┆ 0.059       │
# │      ┆             ┆       ┆         ┆   ┆             ┆             ┆ of a young  ┆             │
# │      ┆             ┆       ┆         ┆   ┆             ┆             ┆ boy who w…  ┆             │
# └──────┴─────────────┴───────┴─────────┴───┴─────────────┴─────────────┴─────────────┴─────────────┘

# %% [markdown]
# Using the `movie` dataset, create a scatter plot with runtime on the x-axis and the IMDB rating on the y-axis.

# %%
(
    movie
    .pipe(ggplot, aes("runtime", "rating"))
    + geom_point()
)
# Out:
# /usr/local/lib/python3.12/dist-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 387 rows containing missing values.

# %% [markdown]
# Create a boxplot showing the distribution of poster brightness for each MPA rating category.

# %%
(
    movie
    .pipe(ggplot, aes("mpa", "poster_brightness"))
    + geom_boxplot(fill="white", color="black")
)
# Out:
# /usr/local/lib/python3.12/dist-packages/plotnine/layer.py:284: PlotnineWarning: stat_boxplot : Removed 461 rows containing non-finite values.

# %% [markdown]
# Now let's start working with multiple tables. Join the `genre` table to the `movie` table. Remember to join on both year and title since some titles appear in multiple years.

# %%
df = (
    genre
    .join(movie, on=[c.year, c.title])
)
df
# Out:
# shape: (11_887, 13)
# ┌──────┬─────────────┬───────────┬─────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ year ┆ title       ┆ genre     ┆ mpa ┆ … ┆ poster_brig ┆ poster_satu ┆ poster_edge ┆ description │
# │ ---  ┆ ---         ┆ ---       ┆ --- ┆   ┆ htness      ┆ ration      ┆ ness        ┆ ---         │
# │ i64  ┆ str         ┆ str       ┆ str ┆   ┆ ---         ┆ ---         ┆ ---         ┆ str         │
# │      ┆             ┆           ┆     ┆   ┆ f64         ┆ f64         ┆ f64         ┆             │
# ╞══════╪═════════════╪═══════════╪═════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ 1970 ┆ Love Story  ┆ Drama     ┆ PG  ┆ … ┆ 79.039734   ┆ 8.029792    ┆ 4.586166    ┆ A boy and a │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ girl from   │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ differen…   │
# │ 1970 ┆ Love Story  ┆ Romance   ┆ PG  ┆ … ┆ 79.039734   ┆ 8.029792    ┆ 4.586166    ┆ A boy and a │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ girl from   │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ differen…   │
# │ 1970 ┆ Airport     ┆ Action    ┆ G   ┆ … ┆ 70.73516    ┆ 29.284572   ┆ 4.954735    ┆ A bomber on │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ board an    │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ airplane,…  │
# │ 1970 ┆ Airport     ┆ Drama     ┆ G   ┆ … ┆ 70.73516    ┆ 29.284572   ┆ 4.954735    ┆ A bomber on │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ board an    │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ airplane,…  │
# │ 1970 ┆ Airport     ┆ Thriller  ┆ G   ┆ … ┆ 70.73516    ┆ 29.284572   ┆ 4.954735    ┆ A bomber on │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ board an    │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ airplane,…  │
# │ …    ┆ …           ┆ …         ┆ …   ┆ … ┆ …           ┆ …           ┆ …           ┆ …           │
# │ 2019 ┆ The         ┆ Romance   ┆ R   ┆ … ┆ 18.4582     ┆ 36.364627   ┆ 2.137566    ┆ Post World  │
# │      ┆ Aftermath   ┆           ┆     ┆   ┆             ┆             ┆             ┆ War II, a   │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ British c…  │
# │ 2019 ┆ The         ┆ War       ┆ R   ┆ … ┆ 18.4582     ┆ 36.364627   ┆ 2.137566    ┆ Post World  │
# │      ┆ Aftermath   ┆           ┆     ┆   ┆             ┆             ┆             ┆ War II, a   │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ British c…  │
# │ 2019 ┆ The Kid     ┆ Biography ┆ R   ┆ … ┆ 27.409446   ┆ 40.325301   ┆ 3.192685    ┆ The story   │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ of a young  │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ boy who w…  │
# │ 2019 ┆ The Kid     ┆ Drama     ┆ R   ┆ … ┆ 27.409446   ┆ 40.325301   ┆ 3.192685    ┆ The story   │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ of a young  │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ boy who w…  │
# │ 2019 ┆ The Kid     ┆ Western   ┆ R   ┆ … ┆ 27.409446   ┆ 40.325301   ┆ 3.192685    ┆ The story   │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ of a young  │
# │      ┆             ┆           ┆     ┆   ┆             ┆             ┆             ┆ boy who w…  │
# └──────┴─────────────┴───────────┴─────┴───┴─────────────┴─────────────┴─────────────┴─────────────┘

# %% [markdown]
# Using the joined data, compute the average poster brightness and average poster saturation for each genre. Then create a scatter plot of these averages with genre labels next to each point.

# %%
(
    df
    .group_by(c.genre)
    .agg(
        poster_brightness_mean = c.poster_brightness.mean(),
        poster_saturation_mean = c.poster_saturation.mean()
    )
    .pipe(ggplot, aes("poster_brightness_mean", "poster_saturation_mean"))
    + geom_point()
    + geom_text(aes(label="genre"), nudge_y=2, size=10)
)

# %% [markdown]
# The `people` table contains information about cast and crew, including a predicted gender and a confidence score for that prediction. Filter the people data to only starring roles where the gender confidence is greater than 0.8. Then join this to the genre table. For each genre, compute the proportion of these roles that are female and the total count. Sort by the proportion of female roles and display all results.

# %%
(
    people
    .filter(c.role == "starring", c.gender_conf>0.8)
    .join(genre, on=[c.year, c.title])
    .group_by(c.genre)
    .agg(
        avg_female = (c.gender == "female").mean(),
        count = pl.count()
    )
    .sort(c.avg_female)
    .pipe(print_rows)
)
# Out:
# /tmp/ipython-input-2247506064.py:8: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
# shape: (21, 3)
# ┌───────────┬────────────┬───────┐
# │ genre     ┆ avg_female ┆ count │
# │ ---       ┆ ---        ┆ ---   │
# │ str       ┆ f64        ┆ u32   │
# ╞═══════════╪════════════╪═══════╡
# │ Short     ┆ 0.0        ┆ 1     │
# │ War       ┆ 0.183099   ┆ 213   │
# │ History   ┆ 0.233516   ┆ 364   │
# │ Western   ┆ 0.247059   ┆ 255   │
# │ Action    ┆ 0.267078   ┆ 4538  │
# │ Crime     ┆ 0.284756   ┆ 3129  │
# │ Adventure ┆ 0.289352   ┆ 3691  │
# │ Sport     ┆ 0.293249   ┆ 474   │
# │ Biography ┆ 0.297017   ┆ 771   │
# │ Animation ┆ 0.299799   ┆ 994   │
# │ Sci-Fi    ┆ 0.308668   ┆ 1419  │
# │ Thriller  ┆ 0.331402   ┆ 2589  │
# │ Comedy    ┆ 0.356179   ┆ 7485  │
# │ Fantasy   ┆ 0.35889    ┆ 1513  │
# │ Drama     ┆ 0.359471   ┆ 7945  │
# │ Music     ┆ 0.364      ┆ 500   │
# │ Family    ┆ 0.364198   ┆ 1458  │
# │ Mystery   ┆ 0.37883    ┆ 1436  │
# │ Musical   ┆ 0.378995   ┆ 219   │
# │ Horror    ┆ 0.385405   ┆ 1754  │
# │ Romance   ┆ 0.433153   ┆ 2775  │
# └───────────┴────────────┴───────┘

# %% [markdown]
# Let's find the most common dominant poster color for each genre. Start with the `color` table and filter to just the hue colors. For each movie, find the color with the highest percentage (this is the dominant hue). Keep only movies where the dominant hue makes up more than 5% of the poster. Join this to the genre table, then count how often each color appears as the dominant hue within each genre. Finally, find the single most common dominant color for each genre.

# %%
color.head()
# Out:
# shape: (5, 5)
# ┌──────┬────────────┬────────────┬────────┬────────────┐
# │ year ┆ title      ┆ color_type ┆ color  ┆ percentage │
# │ ---  ┆ ---        ┆ ---        ┆ ---    ┆ ---        │
# │ i64  ┆ str        ┆ str        ┆ str    ┆ f64        │
# ╞══════╪════════════╪════════════╪════════╪════════════╡
# │ 1970 ┆ Love Story ┆ hue        ┆ red    ┆ 2.635655   │
# │ 1970 ┆ Love Story ┆ hue        ┆ orange ┆ 3.093356   │
# │ 1970 ┆ Love Story ┆ hue        ┆ yellow ┆ 0.054209   │
# │ 1970 ┆ Love Story ┆ hue        ┆ green  ┆ 0.236061   │
# │ 1970 ┆ Love Story ┆ hue        ┆ blue   ┆ 0.319376   │
# └──────┴────────────┴────────────┴────────┴────────────┘

# %%
(
    color
    .filter(c.color_type=="hue")
    .sort(c.percentage, descending=True)
    .group_by(c.year, c.title)
    .head(1)
    .filter(c.percentage > 5)
    .join(genre, on=[c.year, c.title])
    .group_by(c.genre, c.color)
    .agg(count = pl.count())
    .sort(c.count, descending=True)
    .group_by(c.genre)
    .head(1)
    .pipe(print_rows)
)
# Out:
# /tmp/ipython-input-1502940286.py:10: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
# shape: (21, 3)
# ┌───────────┬───────┬───────┐
# │ genre     ┆ color ┆ count │
# │ ---       ┆ ---   ┆ ---   │
# │ str       ┆ str   ┆ u32   │
# ╞═══════════╪═══════╪═══════╡
# │ Comedy    ┆ red   ┆ 1018  │
# │ Biography ┆ red   ┆ 84    │
# │ Family    ┆ red   ┆ 159   │
# │ Animation ┆ blue  ┆ 132   │
# │ War       ┆ red   ┆ 28    │
# │ Short     ┆ red   ┆ 1     │
# │ Adventure ┆ blue  ┆ 374   │
# │ Crime     ┆ red   ┆ 432   │
# │ Sport     ┆ red   ┆ 69    │
# │ Mystery   ┆ red   ┆ 139   │
# │ Action    ┆ red   ┆ 535   │
# │ Horror    ┆ red   ┆ 160   │
# │ Music     ┆ red   ┆ 70    │
# │ Fantasy   ┆ red   ┆ 148   │
# │ Drama     ┆ red   ┆ 971   │
# │ Musical   ┆ red   ┆ 30    │
# │ History   ┆ red   ┆ 39    │
# │ Western   ┆ red   ┆ 30    │
# │ Thriller  ┆ red   ┆ 294   │
# │ Sci-Fi    ┆ blue  ┆ 155   │
# │ Romance   ┆ red   ┆ 436   │
# └───────────┴───────┴───────┘

# %% [markdown]
# Now, let's see an example of how to use an semi-join. First, create a table called `movie_long` that consists of all films that have a run time greater than 2.5 hours (150 minutes).

# %%
movie.head()
# Out:
# shape: (5, 12)
# ┌──────┬──────────────┬─────┬─────────┬───┬──────────────┬─────────────┬─────────────┬─────────────┐
# │ year ┆ title        ┆ mpa ┆ runtime ┆ … ┆ poster_brigh ┆ poster_satu ┆ poster_edge ┆ description │
# │ ---  ┆ ---          ┆ --- ┆ ---     ┆   ┆ tness        ┆ ration      ┆ ness        ┆ ---         │
# │ i64  ┆ str          ┆ str ┆ i64     ┆   ┆ ---          ┆ ---         ┆ ---         ┆ str         │
# │      ┆              ┆     ┆         ┆   ┆ f64          ┆ f64         ┆ f64         ┆             │
# ╞══════╪══════════════╪═════╪═════════╪═══╪══════════════╪═════════════╪═════════════╪═════════════╡
# │ 1970 ┆ Love Story   ┆ PG  ┆ 100     ┆ … ┆ 79.039734    ┆ 8.029792    ┆ 4.586166    ┆ A boy and a │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ girl from   │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ differen…   │
# │ 1970 ┆ Airport      ┆ G   ┆ 137     ┆ … ┆ 70.73516     ┆ 29.284572   ┆ 4.954735    ┆ A bomber on │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ board an    │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ airplane,…  │
# │ 1970 ┆ MASH         ┆ R   ┆ 116     ┆ … ┆ 74.540002    ┆ 40.103629   ┆ 3.510285    ┆ The staff   │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ of a Korean │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ War fiel…   │
# │ 1970 ┆ Patton       ┆ GP  ┆ 172     ┆ … ┆ 83.128991    ┆ 17.43385    ┆ 3.657574    ┆ The World   │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ War II      │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ phase of    │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ the …       │
# │ 1970 ┆ The          ┆ G   ┆ 78      ┆ … ┆ 79.794746    ┆ 12.481992   ┆ 4.400358    ┆ With the    │
# │      ┆ AristoCats   ┆     ┆         ┆   ┆              ┆             ┆             ┆ help of a   │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ smooth      │
# │      ┆              ┆     ┆         ┆   ┆              ┆             ┆             ┆ talk…       │
# └──────┴──────────────┴─────┴─────────┴───┴──────────────┴─────────────┴─────────────┴─────────────┘

# %%
movie_long = (
    movie
    .filter(c.runtime>150)
)

# %% [markdown]
# Then, draw a plot showing the number films that have a long runtime by their genre using a semi-join. Try to make the plot look nice. Note: Yes, you could do this in other ways in this simple case. Semi- and anti-joins are very useful as our analyses become more complex.

# %%
(
    genre
    .join(movie_long, how="semi", on=[c.year, c.title])
    .group_by(c.genre)
    .agg(count = pl.len())
    .pipe(ggplot, aes("reorder(genre, count)", "count"))
    + geom_col()
    + coord_flip()
)

# %% [markdown]
# We've mentioned that some titles are repeated in the data and therefore we always need to group by title and year. Find all of the titles that are repeated. Print all of the rows of the result and order by the counts.

# %%
(
    movie
    .group_by(c.title)
    .agg(count=pl.len())
    .filter(c.count>1)
    .sort(c.count, c.title, descending=True)
    .pipe(print_rows)
)
# Out:
# shape: (92, 2)
# ┌──────────────────────────────┬───────┐
# │ title                        ┆ count │
# │ ---                          ┆ ---   │
# │ str                          ┆ u32   │
# ╞══════════════════════════════╪═══════╡
# │ The Adventures of Pinocchio  ┆ 3     │
# │ Shaft                        ┆ 3     │
# │ Robin Hood                   ┆ 3     │
# │ Hercules                     ┆ 3     │
# │ Halloween                    ┆ 3     │
# │ Godzilla                     ┆ 3     │
# │ When a Stranger Calls        ┆ 2     │
# │ Vacation                     ┆ 2     │
# │ Twilight                     ┆ 2     │
# │ Total Recall                 ┆ 2     │
# │ Threesome                    ┆ 2     │
# │ The Three Musketeers         ┆ 2     │
# │ The Strangers                ┆ 2     │
# │ The Stepford Wives           ┆ 2     │
# │ The Rookie                   ┆ 2     │
# │ The Player                   ┆ 2     │
# │ The Omen                     ┆ 2     │
# │ The Mummy                    ┆ 2     │
# │ The Lion King                ┆ 2     │
# │ The Last House on the Left   ┆ 2     │
# │ The Kid                      ┆ 2     │
# │ The Karate Kid               ┆ 2     │
# │ The Jungle Book              ┆ 2     │
# │ The Island of Dr. Moreau     ┆ 2     │
# │ The Island                   ┆ 2     │
# │ The Intruder                 ┆ 2     │
# │ The Hills Have Eyes          ┆ 2     │
# │ The Heartbreak Kid           ┆ 2     │
# │ The Guardian                 ┆ 2     │
# │ The Green Hornet             ┆ 2     │
# │ The Getaway                  ┆ 2     │
# │ The Fog                      ┆ 2     │
# │ The Crazies                  ┆ 2     │
# │ The Circle                   ┆ 2     │
# │ The Avengers                 ┆ 2     │
# │ The Animal                   ┆ 2     │
# │ The Amityville Horror        ┆ 2     │
# │ The Addams Family            ┆ 2     │
# │ Teenage Mutant Ninja Turtles ┆ 2     │
# │ Sparkle                      ┆ 2     │
# │ Serenity                     ┆ 2     │
# │ Scream                       ┆ 2     │
# │ Sahara                       ┆ 2     │
# │ RoboCop                      ┆ 2     │
# │ Red Dawn                     ┆ 2     │
# │ Project X                    ┆ 2     │
# │ Poltergeist                  ┆ 2     │
# │ Point Break                  ┆ 2     │
# │ Pete's Dragon                ┆ 2     │
# │ Pet Sematary                 ┆ 2     │
# │ Overboard                    ┆ 2     │
# │ Nobody's Fool                ┆ 2     │
# │ No Escape                    ┆ 2     │
# │ Night School                 ┆ 2     │
# │ Neighbors                    ┆ 2     │
# │ My Little Pony: The Movie    ┆ 2     │
# │ Mother Knows Best            ┆ 2     │
# │ Mother                       ┆ 2     │
# │ Life                         ┆ 2     │
# │ Les Misérables               ┆ 2     │
# │ King Kong                    ┆ 2     │
# │ Hot Pursuit                  ┆ 2     │
# │ Hellboy                      ┆ 2     │
# │ Halloween II                 ┆ 2     │
# │ Hairspray                    ┆ 2     │
# │ Grease 2                     ┆ 2     │
# │ Grease                       ┆ 2     │
# │ Gone in 60 Seconds           ┆ 2     │
# │ Going in Style               ┆ 2     │
# │ Gladiator                    ┆ 2     │
# │ Ghostbusters                 ┆ 2     │
# │ Friday the 13th              ┆ 2     │
# │ Freaky Friday                ┆ 2     │
# │ Footloose                    ┆ 2     │
# │ Fantastic Four               ┆ 2     │
# │ Emma                         ┆ 2     │
# │ Death Wish                   ┆ 2     │
# │ Dawn of the Dead             ┆ 2     │
# │ Crossroads                   ┆ 2     │
# │ Clash of the Titans          ┆ 2     │
# │ Child's Play                 ┆ 2     │
# │ Charlotte's Web              ┆ 2     │
# │ Carrie                       ┆ 2     │
# │ Billy Boy                    ┆ 2     │
# │ Beauty and the Beast         ┆ 2     │
# │ Bad Boys                     ┆ 2     │
# │ Arthur                       ┆ 2     │
# │ Annie                        ┆ 2     │
# │ Aladdin                      ┆ 2     │
# │ A Star Is Born               ┆ 2     │
# │ A Nightmare on Elm Street    ┆ 2     │
# │ A Christmas Carol            ┆ 2     │
# └──────────────────────────────┴───────┘
